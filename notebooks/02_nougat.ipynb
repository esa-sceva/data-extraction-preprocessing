# %%
# !pip install albumentations==1.0 # pin this version, else runs into a pydantic issue
# pip install transformers==4.38.2

# %%
import os
from tqdm.auto import tqdm

directory_path = '../data/extraction_metrics/files/'
output_path = 'output'

for filename in tqdm(os.listdir(directory_path)):
    if filename.endswith('.pdf'):
        file_path = os.path.join(directory_path, filename)
        os.system(f'nougat pdf {file_path} -o {output_path}')
